# %%
import seaborn as sns
import pandas as pd
import numpy as np
import scipy.stats as st

# %%
sales = pd.read_excel(".\sales.xlsx")

# %%
sales.head(2)
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity     Sales  \
# 0       1         3 2010-10-13            Low               6    261.54
# 1      49       293 2012-10-01           High              49  10123.02
#
#    Discount       Ship Mode  Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air -213.25       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck  457.81      208.16  ...        Barry French
#
#   Province   Region Customer Segment Product Category    Product Sub-Category  \
# 0  Nunavut  Nunavut   Small Business  Office Supplies  Storage & Organization
# 1  Nunavut  Nunavut         Consumer  Office Supplies              Appliances
#
#                                         Product Name Product Container  \
# 0   Eldon Base for stackable storage shelf, platinum         Large Box
# 1  1.7 Cubic Foot Compact "Cube" Office Refrigera...        Jumbo Drum
#
#   Product Base Margin  Ship Date
# 0                0.80 2010-10-20
# ...

# %%
sns.displot(sales.Profit[(sales.Region == 'West')])

# %%
df = pd.read_excel('.\sales.xlsx')
datalist = df['Profit'][(sales.Region == 'West')].tolist()
print (datalist)
# Out:
# [70.8, -160.46, 7.69, 717.12, 741.27, -66.05, 60.72, 48.987, 489.02, 109.33, -211.13, -28.46, -60.39, -7.61, 205.83, 52.53, 271.87, 4.58, 177.66, 734.75, -109.1, 195.16, 1196.37, -379.29, 78.86, -912.08, -261.612, 14.49, 88.72, 17.05, 552.97, -270.0, -43.21, -108.28, -73.14, -73.66, 9.59, -655.424, -12.38, -95.54, -69.91, 2369.844, -457.16, -517.17, -429.86, 365.418, -14.1, -63.72, 14.346, -10.7295, 3051.62, -7.728, -187.75, -33.82, 319.52, -13.95, -136.2, -88.6075, -70.04, 27.22, 46.41, -8.02, -47.12, 218.727, -183.356, -129.53, -72.28, 115.21, 6.84, -18.3425, -27.92, -164.46099999999998, 935.8000000000005, -4.485, -101.24600000000001, -1.88, 339.745, -57.753, -47.97, 24.561, 38.02, 29.21, 418.19, -191.49, -21.2, 39.63, 26.21, -43.96, 51.36, 25.95, 884.907, -175.86, -15.44, 650.73, -43.5, -131.31, 16.23, 267.16, 590.77, -2.31, 1243.17, 1325.817, -133.68, 1176.48, 1265.82, 394.452, 709.325, 2.822, -116.45, -11.69, -94.76, 5.015, 39.9, 437.07, -10.4765, 42.76, 48.45, -38.72, 182.15, -
# ...

# %%
x = np.array(datalist)
StandDev = x.std()
print (StandDev)
# Out:
# 1264.6324607572726

# %%
Sum = sum(datalist)
avg = Sum/len(datalist)
print(avg)
# Out:
# 149.1755781165244

# %%
ZscoreA = (5000-avg)/StandDev
print (ZscoreA)
# Out:
# 3.8357582715999246

# %%
ZscoreB = (100-avg)/StandDev
print (ZscoreB)
# Out:
# -0.038885272711628525

# %%
print(st.norm.cdf(ZscoreA) - st.norm.cdf(ZscoreB))
# Out:
# 0.5154464820776321
